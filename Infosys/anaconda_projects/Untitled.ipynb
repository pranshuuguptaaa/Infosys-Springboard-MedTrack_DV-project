# %%
import pandas as pd

df = pd.read_csv("../data/processed/hospital_cleaned.csv")
df.head()

# %%
df = pd.read_csv("data/processed/hospital_cleaned.csv")
df.head()

# %%
raw = pd.read_csv("../data/raw/hospital_raw_data.csv")
raw.head()
